# %%
import pandas as pd
import numpy as np

data = pd.read_csv('matchinfo.csv')
roles = ["Year", "Season","bResult","redTopChamp","redJungleChamp", "redMiddleChamp", "redADCChamp", "redSupportChamp","blueTopChamp","blueJungleChamp", "blueMiddleChamp", "blueADCChamp", "blueSupportChamp"]
data[roles].head()
# Out:
#    Year  Season  bResult redTopChamp redJungleChamp redMiddleChamp  \
# 0  2015  Spring        1        Gnar          Elise           Fizz
# 1  2015  Spring        0      Irelia       JarvanIV           Azir
# 2  2015  Spring        1        Sion         LeeSin           Azir
# 3  2015  Spring        0        Gnar           Nunu           Lulu
# 4  2015  Spring        1        Sion         RekSai           Lulu
#
#   redADCChamp redSupportChamp blueTopChamp blueJungleChamp blueMiddleChamp  \
# 0       Sivir          Thresh       Irelia          RekSai            Ahri
# 1       Corki           Annie         Gnar          Rengar            Ahri
# 2       Corki           Janna     Renekton          Rengar            Fizz
# 3      KogMaw           Janna       Irelia        JarvanIV         Leblanc
# 4       Corki           Annie         Gnar        JarvanIV       Lissandra
#
#   blueADCChamp blueSupportChamp
# 0         Jinx            Janna
# 1      Caitlyn            Leona
# ...
