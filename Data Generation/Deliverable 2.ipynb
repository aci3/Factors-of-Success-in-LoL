# %%
import pandas as pd
pd.set_option('display.max_columns', 999)
import numpy as np

input_file = 'C:\\Users\\Rami\\Desktop\\RiotAPI\\lol_data_3.csv'
df = pd.read_csv(input_file)
df.head()
# Out:
#            id        version       side    win      ban1      ban2  \
# 0  3311986735  10.4.308.9400  Side.blue  False  Katarina  Aphelios
# 1  3311986735  10.4.308.9400   Side.red   True     Vayne    Darius
# 2  3310027121  10.4.308.9400  Side.blue   True      Sett     Diana
# 3  3310027121  10.4.308.9400   Side.red  False    Illaoi      Olaf
# 4  3303576665  10.4.308.9400  Side.blue   True      Sett     Senna
#
#           ban3       ban4      ban5 champion1 champion2 champion3  \
# 0        Garen      Shaco      Sett      Ekko     Nasus     Leona
# 1   Blitzcrank  Master Yi  Aphelios   Caitlyn   Rek'Sai      Sion
# 2    Master Yi    Morgana  Aphelios   Karthus   Caitlyn       Zoe
# 3  Mordekaiser   Aphelios      Ornn   Kha'Zix       Lux     Kayle
# 4       Darius  Master Yi    Soraka   Trundle       Zoe     Fiora
#
#       champion4     champion5  tower_kills  inhibitor_kills  dragon_kills  \
# 0  Heimerdinger           Zed            1                0             0
# ...

# %%
df
# Out:
#             id        version       side    win        ban1         ban2  \
# 0   3311986735  10.4.308.9400  Side.blue  False    Katarina     Aphelios
# 1   3311986735  10.4.308.9400   Side.red   True       Vayne       Darius
# 2   3310027121  10.4.308.9400  Side.blue   True        Sett        Diana
# 3   3310027121  10.4.308.9400   Side.red  False      Illaoi         Olaf
# 4   3303576665  10.4.308.9400  Side.blue   True        Sett        Senna
# 5   3303576665  10.4.308.9400   Side.red  False    Aphelios        Garen
# 6   3303529002  10.4.308.9400  Side.blue  False       Sylas        Vayne
# 7   3303529002  10.4.308.9400   Side.red   True       Yasuo       Darius
# 8   3303470666  10.4.308.9400  Side.blue   True    Tristana    Master Yi
# 9   3303470666  10.4.308.9400   Side.red  False     Lee Sin        Yasuo
# 10  3325060637   10.5.312.392  Side.blue   True     Warwick        Diana
# 11  3325060637   10.5.312.392   Side.red  False      Illaoi        Akali
# ...
